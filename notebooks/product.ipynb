# %%
import tensorflow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
import numpy as np
import pandas as pd
from numpy.linalg import norm
import os
from tqdm import tqdm
import pickle
import PIL

# %%
print(PIL.__version__)
# Out:
# 9.0.1

# %%
model = ResNet50(weights="imagenet", include_top=False, input_shape=(60,80,3))
model.trainable = False

model = tensorflow.keras.Sequential([
    model,
    GlobalMaxPooling2D()
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2, 3, 2048)        23587712
#
#  global_max_pooling2d (Globa  (None, 2048)             0
#  lMaxPooling2D)
#
# =================================================================
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
def feature_extraction(img_path, model):
    img = image.load_img(img_path, target_size=(60,80))
    img_array = image.img_to_array(img)
    expanded_img_array = np.expand_dims(img_array, axis=0)
    preprocessed_img = preprocess_input(expanded_img_array)
    result = model.predict(preprocessed_img).flatten()
    normalized_result = result /  norm(result)

    return normalized_result

# %%
filenames = []

for file in os.listdir('images'):
    filenames.append(os.path.join('images', file))

feature_list = []

for file in tqdm(filenames):
    feature_list.append(feature_extraction(file, model))
# Out:
# 100%|██████████| 9999/9999 [18:21<00:00,  9.08it/s]

# %%
pickle.dump(feature_list, open('image-embed.pkl', 'wb'))

# %%
pickle.dump(filenames, open('file-name.pkl', 'wb'))

# %%
model.save('my_model_2.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# C:\Users\Ellefson\miniconda3\envs\ai-npl\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
import urllib.request

# %%
df = pd.read_csv('../data/dataset/newdata.csv')

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
# Out:
#           id gender masterCategory subCategory            articleType  \
# 0      15970    Men        Apparel     Topwear                 Shirts
# 1      39386    Men        Apparel  Bottomwear                  Jeans
# 2      59263  Women    Accessories     Watches                Watches
# 3      21379    Men        Apparel  Bottomwear            Track Pants
# 4      53759    Men        Apparel     Topwear                Tshirts
# ...      ...    ...            ...         ...                    ...
# 44094  17036    Men       Footwear       Shoes           Casual Shoes
# 44095   6461    Men       Footwear  Flip Flops             Flip Flops
# 44096  18842    Men        Apparel     Topwear                Tshirts
# 44097  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44098  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season  year   usage  \
# 0      Navy Blue    Fall  2011  Casual
# 1           Blue  Summer  2012  Casual
# 2         Silver  Winter  2016  Casual
# 3          Black    Fall  2011  Casual
# 4           Grey  Summer  2012  Casual
# ...          ...     ...   ...     ...
# 44094      White  Summer  2013  Casual
# 44095        Red  Summer  2011  Casual
# 44096       Blue    Fall  2011  Casual
# 44097       Blue  Spring  2017  Casual
# 44098       Pink  Winter  2016  Casual
#
#                                     productDisplayName  \
# 0                     Turtle Check Men Navy Blue Shirt
# 1                   Peter England Men Party Blue Jeans
# 2                             Titan Women Silver Watch
# 3        Manchester United Men Solid Black Track Pants
# 4                                Puma Men Grey T-shirt
# ...                                                ...
# 44094                        Gas Men Caddy Casual Shoe
# 44095               Lotto Men's Soccer Track Flip Flop
# 44096             Puma Men Graphic Stellar Blue Tshirt
# 44097                   Rasasi Women Blue Lady Perfume
# 44098  Fossil Women Pink Dial Chronograph Watch ES3050
#
#                                                    image   filename
# 0      http://assets.myntassets.com/v1/images/style/p...  15970.jpg
# 1      http://assets.myntassets.com/v1/images/style/p...  39386.jpg
# 2      http://assets.myntassets.com/v1/images/style/p...  59263.jpg
# 3      http://assets.myntassets.com/v1/images/style/p...  21379.jpg
# 4      http://assets.myntassets.com/v1/images/style/p...  53759.jpg
# ...                                                  ...        ...
# 44094  http://assets.myntassets.com/v1/images/style/p...  17036.jpg
# 44095  http://assets.myntassets.com/v1/images/style/p...   6461.jpg
# 44096  http://assets.myntassets.com/v1/images/style/p...  18842.jpg
# 44097  http://assets.myntassets.com/v1/images/style/p...  46694.jpg
# 44098  http://assets.myntassets.com/assets/images/516...  51623.jpg
#
# [44099 rows x 12 columns]

# %%
# Out:
# ('local-filename.jpg', <http.client.HTTPMessage at 0x1b8586d2a08>)

# %%
product_df = df.sample(15000)

# %%
product_df
# Out:
#           id gender masterCategory subCategory   articleType baseColour  \
# 3777   57334  Women        Apparel   Innerwear           Bra       Grey
# 17190  55275  Women  Personal Care      Makeup       Compact       Pink
# 10304  16028    Men        Apparel     Topwear        Shirts        Red
# 40430  24649    Men       Footwear       Shoes  Casual Shoes      Black
# 25071  59232    Men    Accessories     Watches       Watches      Black
# ...      ...    ...            ...         ...           ...        ...
# 34055  28909  Women        Apparel     Topwear        Kurtas        Red
# 7853   59577    Men    Accessories   Cufflinks     Cufflinks      Steel
# 10084  22222  Women        Apparel     Topwear       Tshirts      White
# 5055   38654    Men       Footwear       Shoes  Sports Shoes      White
# 18356  39993    Men       Footwear       Shoes  Casual Shoes      Black
#
#        season  year   usage                             productDisplayName  \
# 3777   Winter  2015  Casual                              Amante Bra BCSO01
# 17190  Summer  2019  Casual               Lakme Rose Powder With Sunscreen
# 10304    Fall  2011  Casual                 Highlander Men Check Red Shirt
# 40430  Summer  2013  Casual  Converse Men's As Canvas Hi Black Denim Shoes
# 25071  Winter  2016  Casual                          Titan Men Black Watch
# ...       ...   ...     ...                                            ...
# 34055  Summer  2012  Ethnic                   BIBA Women Printed Red Kurta
# 7853   Summer  2012  Casual             Revv Men Steel and Brown Cufflinks
# 10084    Fall  2011  Casual          Little Miss Women Magic White T-shirt
# 5055     Fall  2012  Sports           Nike Men Ballista White Sports Shoes
# 18356  Summer  2013  Casual                       Gas Men Draw Black Shoes
#
#                                                    image   filename
# 3777   http://assets.myntassets.com/v1/images/style/p...  57334.jpg
# 17190  http://assets.myntassets.com/v1/images/style/p...  55275.jpg
# 10304  http://assets.myntassets.com/v1/images/style/p...  16028.jpg
# 40430  http://assets.myntassets.com/v1/images/style/p...  24649.jpg
# 25071  http://assets.myntassets.com/v1/images/style/p...  59232.jpg
# ...                                                  ...        ...
# 34055  http://assets.myntassets.com/v1/images/style/p...  28909.jpg
# 7853   http://assets.myntassets.com/v1/images/style/p...  59577.jpg
# 10084  http://assets.myntassets.com/v1/images/style/p...  22222.jpg
# 5055   http://assets.myntassets.com/v1/images/style/p...  38654.jpg
# 18356  http://assets.myntassets.com/v1/images/style/p...  39993.jpg
#
# [15000 rows x 12 columns]
