# %%
import joblib
import numpy as np
import pandas as pd
import tensorflow
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.preprocessing import image
from tensorflow import keras
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from numpy.linalg import norm
from sklearn.neighbors import NearestNeighbors
from PIL import Image
import requests
from tqdm import tqdm
import os
from shutil import copy

# %%
# Reading the Dataset having aaprox. 44000 records
df = pd.read_csv('../data/dataset/newdata.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.loc[df["subCategory"] == "Watches", "subCategory"] = 'Watch'
df.loc[df["articleType"] == "Watches", "articleType"] = 'Watch'

# %%
ring = df[(df['articleType'] == 'Ring')]

# %%
ring
# Out:
#           id gender masterCategory subCategory articleType baseColour  season  \
# 121    49005  Women    Accessories   Jewellery        Ring     Silver  Summer
# 576    48927  Women    Accessories   Jewellery        Ring     Silver  Summer
# 736    49034  Women    Accessories   Jewellery        Ring     Silver  Summer
# 1060   48929  Women    Accessories   Jewellery        Ring     Silver    Fall
# 1094   49033  Women    Accessories   Jewellery        Ring     Silver  Summer
# ...      ...    ...            ...         ...         ...        ...     ...
# 43622  48963    Men    Accessories   Jewellery        Ring      Steel  Summer
# 43766  49041  Women    Accessories   Jewellery        Ring     Silver    Fall
# 43846  59471  Women    Accessories   Jewellery        Ring     Silver  Summer
# 43985  48990  Women    Accessories   Jewellery        Ring     Silver  Summer
# 44041  48964    Men    Accessories   Jewellery        Ring      Steel  Summer
#
#        year   usage        productDisplayName  \
# 121    2012  Casual  Lucera Women Silver Ring
# 576    2012  Casual  Lucera Women Silver Ring
# 736    2012  Casual  Lucera Women Silver Ring
# 1060   2012  Casual  Lucera Women Silver Ring
# 1094   2012  Casual  Lucera Women Silver Ring
# ...     ...     ...                       ...
# 43622  2013  Casual       Revv Men Steel Ring
# 43766  2012  Casual  Lucera Women Silver Ring
# 43846  2013  Casual        Lucera Silver Ring
# 43985  2012  Casual  Lucera Women Silver Ring
# 44041  2012  Casual       Revv Men Steel Ring
#
#                                                    image   filename
# 121    http://assets.myntassets.com/v1/images/style/p...  49005.jpg
# 576    http://assets.myntassets.com/v1/images/style/p...  48927.jpg
# 736    http://assets.myntassets.com/v1/images/style/p...  49034.jpg
# 1060   http://assets.myntassets.com/v1/images/style/p...  48929.jpg
# 1094   http://assets.myntassets.com/v1/images/style/p...  49033.jpg
# ...                                                  ...        ...
# 43622  http://assets.myntassets.com/v1/images/style/p...  48963.jpg
# 43766  http://assets.myntassets.com/v1/images/style/p...  49041.jpg
# 43846  http://assets.myntassets.com/v1/images/style/p...  59471.jpg
# 43985  http://assets.myntassets.com/v1/images/style/p...  48990.jpg
# 44041  http://assets.myntassets.com/v1/images/style/p...  48964.jpg
#
# [118 rows x 12 columns]

# %%
ties_option = ['Black', 'White', 'Brown', 'Blue', 'Red']
ties = df[(df['articleType'] == 'Ties') & (df['baseColour'].isin(ties_option))]

# %%
nailpolish = df[(df['articleType'] == 'Nail Polish')]

# %%
nailpolish
# Out:
#           id gender masterCategory subCategory  articleType baseColour  \
# 933    56473  Women  Personal Care       Nails  Nail Polish     Purple
# 1311   56480  Women  Personal Care       Nails  Nail Polish      Brown
# 1603   55894  Women  Personal Care       Nails  Nail Polish       Blue
# 1702   55860  Women  Personal Care       Nails  Nail Polish   Lavender
# 1785   55858  Women  Personal Care       Nails  Nail Polish      Brown
# ...      ...    ...            ...         ...          ...        ...
# 43191  55877  Women  Personal Care       Nails  Nail Polish     Purple
# 43371  55848  Women  Personal Care       Nails  Nail Polish      Peach
# 43516  55841  Women  Personal Care       Nails  Nail Polish       Pink
# 43837  55846  Women  Personal Care       Nails  Nail Polish       Pink
# 43908  55879  Women  Personal Care       Nails  Nail Polish      Green
#
#        season  year   usage                            productDisplayName  \
# 933    Spring  2017  Casual       Streetwear Grape Shimmer Nail Polish 41
# 1311   Spring  2017  Casual            Streetwear Chocolat Nail Polish 20
# 1603   Spring  2017  Casual          Colorbar Blue Lagoon Nail Lacquer 05
# 1702   Spring  2017  Casual  Colorbar Pro Dazzling Mauve Nail Lacquer 008
# 1785   Spring  2017  Casual           Colorbar Pro Flirt Nail Lacquer 013
# ...       ...   ...     ...                                           ...
# 43191  Spring  2017  Casual            Colorbar Exclusive Nail Lacquer 71
# 43371  Spring  2017  Casual      Colorbar Pro Peach Rose Nail Lacquer 047
# 43516  Spring  2017  Casual       Colorbar Pro Pink Late Nail Lacquer 056
# 43837  Spring  2017  Casual   Colorbar Pro Pleasing Pink Nail Lacquer 049
# 43908  Spring  2017  Casual            Colorbar Exclusive Nail Lacquer 60
#
#                                                    image   filename
# 933    http://assets.myntassets.com/v1/images/style/p...  56473.jpg
# 1311   http://assets.myntassets.com/v1/images/style/p...  56480.jpg
# 1603   http://assets.myntassets.com/assets/images/558...  55894.jpg
# 1702   http://assets.myntassets.com/assets/images/558...  55860.jpg
# 1785   http://assets.myntassets.com/v1/images/style/p...  55858.jpg
# ...                                                  ...        ...
# 43191  http://assets.myntassets.com/assets/images/558...  55877.jpg
# 43371  http://assets.myntassets.com/assets/images/558...  55848.jpg
# 43516  http://assets.myntassets.com/assets/images/558...  55841.jpg
# 43837  http://assets.myntassets.com/assets/images/558...  55846.jpg
# 43908  http://assets.myntassets.com/assets/images/558...  55879.jpg
#
# [278 rows x 12 columns]

# %%
deodrant = df[(df['articleType'] == 'Deodorant')]
deodrant
# Out:
#           id gender masterCategory subCategory articleType baseColour  season  \
# 24     18461    Men  Personal Care   Fragrance   Deodorant      White  Spring
# 181    26735    Men  Personal Care   Fragrance   Deodorant      Black  Spring
# 186    58980  Women  Personal Care   Fragrance   Deodorant       Pink  Spring
# 234    58974    Men  Personal Care   Fragrance   Deodorant       Gold  Spring
# 324    46624    Men  Personal Care   Fragrance   Deodorant       Grey  Spring
# ...      ...    ...            ...         ...         ...        ...     ...
# 43737  46667    Men  Personal Care   Fragrance   Deodorant      Brown  Spring
# 43789  28244    Men  Personal Care   Fragrance   Deodorant       Blue  Spring
# 43938  26785    Men  Personal Care   Fragrance   Deodorant        Red  Spring
# 43946  46660    Men  Personal Care   Fragrance   Deodorant       Grey  Spring
# 44011  32527    Men  Personal Care   Fragrance   Deodorant       Blue  Spring
#
#        year   usage                                 productDisplayName  \
# 24     2017  Casual                   David Beckham Signature Men Deos
# 181    2017  Casual  Reebok Men Pack of 2 Pirates of the Caribbean ...
# 186    2017  Casual                        Colour me Women Flowers Deo
# 234    2017  Casual                             Colour me Men Gold Deo
# 324    2017  Casual             Rasasi Men Emotion Deo and Perfume Set
# ...     ...     ...                                                ...
# 43737  2017  Casual                          Rasasi Men Numero Due Deo
# 43789  2017  Casual                      Park Avenue Men Cool Blue Deo
# 43938  2017  Casual                          Reebok Men Pack of 3 Deos
# 43946  2017  Casual                                     Rasasi Men Deo
# 44011  2017  Casual                   Tonino Lamborghini Men Forza Deo
#
#                                                    image   filename
# 24     http://assets.myntassets.com/v1/images/style/p...  18461.jpg
# 181    http://assets.myntassets.com/v1/images/style/p...  26735.jpg
# 186    http://assets.myntassets.com/v1/images/style/p...  58980.jpg
# 234    http://assets.myntassets.com/v1/images/style/p...  58974.jpg
# 324    http://assets.myntassets.com/v1/images/style/p...  46624.jpg
# ...                                                  ...        ...
# 43737  http://assets.myntassets.com/v1/images/style/p...  46667.jpg
# 43789  http://assets.myntassets.com/v1/images/style/p...  28244.jpg
# 43938  http://assets.myntassets.com/v1/images/style/p...  26785.jpg
# 43946  http://assets.myntassets.com/v1/images/style/p...  46660.jpg
# 44011  http://assets.myntassets.com/v1/images/style/p...  32527.jpg
#
# [347 rows x 12 columns]

# %%
options = ['Black', 'White', 'Blue']
jeans = df[(df['articleType'] == 'Jeans') & (df['baseColour'].isin(options)) & (df['gender'] == 'Men')]
jeans
# Out:
#           id gender masterCategory subCategory articleType baseColour  season  \
# 1      39386    Men        Apparel  Bottomwear       Jeans       Blue  Summer
# 335    16508    Men        Apparel  Bottomwear       Jeans       Blue    Fall
# 398    11349    Men        Apparel  Bottomwear       Jeans       Blue  Summer
# 455    39381    Men        Apparel  Bottomwear       Jeans      Black  Summer
# 888    11340    Men        Apparel  Bottomwear       Jeans       Blue  Summer
# ...      ...    ...            ...         ...         ...        ...     ...
# 43706  48399    Men        Apparel  Bottomwear       Jeans       Blue  Summer
# 43719  11332    Men        Apparel  Bottomwear       Jeans       Blue    Fall
# 43928  11335    Men        Apparel  Bottomwear       Jeans       Blue    Fall
# 44040  23455    Men        Apparel  Bottomwear       Jeans       Blue  Summer
# 44047  10445    Men        Apparel  Bottomwear       Jeans       Blue    Fall
#
#        year   usage                               productDisplayName  \
# 1      2012  Casual               Peter England Men Party Blue Jeans
# 335    2011  Casual                 Locomotive Men Washed Blue Jeans
# 398    2017  Casual                   Lee Men Blue Chicago Fit Jeans
# 455    2012  Casual              Peter England Men Party Black Jeans
# 888    2017  Casual                   Lee Men Blue Chicago Fit Jeans
# ...     ...     ...                                              ...
# 43706  2012  Casual                 French Connection Men Blue Jeans
# 43719  2011  Casual  United Colors of Benetton Men Washed Blue Jeans
# 43928  2011  Casual  United Colors of Benetton Men Washed Blue Jeans
# 44040  2012  Casual           Deni Yo Men Blue Washed Slim Fit Jeans
# 44047  2011  Casual            Flying Machine Men Midrise Blue Jeans
#
#                                                    image   filename
# 1      http://assets.myntassets.com/v1/images/style/p...  39386.jpg
# 335    http://assets.myntassets.com/v1/images/style/p...  16508.jpg
# 398    http://assets.myntassets.com/v1/images/style/p...  11349.jpg
# 455    http://assets.myntassets.com/v1/images/style/p...  39381.jpg
# 888    http://assets.myntassets.com/v1/images/style/p...  11340.jpg
# ...                                                  ...        ...
# 43706  http://assets.myntassets.com/v1/images/style/p...  48399.jpg
# 43719  http://assets.myntassets.com/v1/images/style/p...  11332.jpg
# 43928  http://assets.myntassets.com/v1/images/style/p...  11335.jpg
# 44040  http://assets.myntassets.com/v1/images/style/p...  23455.jpg
# 44047  http://assets.myntassets.com/v1/images/style/p...  10445.jpg
#
# [297 rows x 12 columns]

# %%
options_trousers = ['Black', 'White', 'Grey']
trousers = df[(df['articleType'] == 'Trousers') & (df['baseColour'].isin(options_trousers))]
trousers
# Out:
#           id gender masterCategory subCategory articleType baseColour  season  \
# 164    10257    Men        Apparel  Bottomwear    Trousers      Black    Fall
# 219    26163    Men        Apparel  Bottomwear    Trousers       Grey  Summer
# 586    26164    Men        Apparel  Bottomwear    Trousers       Grey  Summer
# 799    10259    Men        Apparel  Bottomwear    Trousers      Black    Fall
# 884    27622    Men        Apparel  Bottomwear    Trousers       Grey  Summer
# ...      ...    ...            ...         ...         ...        ...     ...
# 43105  39797    Men        Apparel  Bottomwear    Trousers      Black  Summer
# 43194  43912  Women        Apparel  Bottomwear    Trousers      Black  Summer
# 43200  39763  Women        Apparel  Bottomwear    Trousers       Grey    Fall
# 43527  21598    Men        Apparel  Bottomwear    Trousers      Black    Fall
# 43548  39103    Men        Apparel  Bottomwear    Trousers       Grey  Summer
#
#        year   usage                         productDisplayName  \
# 164    2011  Formal  John Miller Men Solid Type Black Trousers
# 219    2012  Formal         John Miller Men Dark Grey Trousers
# 586    2012  Formal      John Miller Men Striped Grey Trousers
# 799    2011  Formal      John Miller Men Reglur Black Trousers
# 884    2012  Casual                 Scullers Men Grey Trousers
# ...     ...     ...                                        ...
# 43105  2012  Formal    Peter England Men Black Formal Trousers
# 43194  2012  Casual               Femella Women Black Trousers
# 43200  2012  Formal                  Arrow Woman Grey Trousers
# 43527  2011  Formal             Arrow Men Solid Black Trousers
# 43548  2012  Formal             Reid & Taylor Men Grey Trouser
#
#                                                    image   filename
# 164    http://assets.myntassets.com/v1/images/style/p...  10257.jpg
# 219    http://assets.myntassets.com/v1/images/style/p...  26163.jpg
# 586    http://assets.myntassets.com/v1/images/style/p...  26164.jpg
# 799    http://assets.myntassets.com/v1/images/style/p...  10259.jpg
# 884    http://assets.myntassets.com/v1/images/style/p...  27622.jpg
# ...                                                  ...        ...
# 43105  http://assets.myntassets.com/v1/images/style/p...  39797.jpg
# 43194  http://assets.myntassets.com/v1/images/style/p...  43912.jpg
# 43200  http://assets.myntassets.com/v1/images/style/p...  39763.jpg
# 43527  http://assets.myntassets.com/v1/images/style/p...  21598.jpg
# 43548  http://assets.myntassets.com/v1/images/style/p...  39103.jpg
#
# [227 rows x 12 columns]

# %%
from sklearn.utils import shuffle
options_socks = ['Black', 'White', 'Grey']
socks = df[(df['articleType'] == 'Socks') & (df['baseColour'].isin(options_socks))]
socks = shuffle(socks)
socks = socks.head(300)

# %%
socks.groupby('baseColour')['baseColour'].count().nlargest()
# Out:
# baseColour
# Black    131
# White    114
# Grey      55
# Name: baseColour, dtype: int64

# %%
socks
# Out:
#           id  gender masterCategory subCategory articleType baseColour  \
# 12724  29214   Women    Accessories       Socks       Socks      White
# 8762   32026     Men    Accessories       Socks       Socks       Grey
# 28450  51148     Men    Accessories       Socks       Socks      Black
# 39268  18217     Men    Accessories       Socks       Socks       Grey
# 25252  54343     Men    Accessories       Socks       Socks      White
# ...      ...     ...            ...         ...         ...        ...
# 21325  54339     Men    Accessories       Socks       Socks      Black
# 14848   9355     Men    Accessories       Socks       Socks      White
# 21246  46862     Men    Accessories       Socks       Socks      Black
# 3871   29115     Men    Accessories       Socks       Socks      White
# 13015  53806  Unisex    Accessories       Socks       Socks      White
#
#        season  year   usage                        productDisplayName  \
# 12724    Fall  2014  Sports                    Fila Women White Socks
# 8762   Summer  2016  Casual          Playboy Men Multi Coloured Socks
# 28450  Summer  2016  Casual                      Parx Men Black Socks
# 39268    Fall  2011  Casual    Manchester United Men Solid Grey Socks
# 25252  Summer  2016  Casual                 Levis Men Pack of 3 Socks
# ...       ...   ...     ...                                       ...
# 21325  Summer  2016  Casual                 Levis Men Pack of 3 Socks
# 14848    Fall  2011  Casual      Puma Men Sport Pack of 3 White Socks
# 21246  Summer  2012  Casual           Lino Perros Men Pack of 2 Socks
# 3871   Summer  2012  Casual  Puma Men Foundation Quarters White Socks
# 13015  Summer  2012  Casual          Puma Kids Unisex Pack of 3 Socks
#
#                                                    image   filename
# 12724  http://assets.myntassets.com/v1/images/style/p...  29214.jpg
# 8762   http://assets.myntassets.com/v1/images/style/p...  32026.jpg
# 28450  http://assets.myntassets.com/v1/images/style/p...  51148.jpg
# 39268  http://assets.myntassets.com/v1/images/style/p...  18217.jpg
# 25252  http://assets.myntassets.com/v1/images/style/p...  54343.jpg
# ...                                                  ...        ...
# 21325  http://assets.myntassets.com/v1/images/style/p...  54339.jpg
# 14848  http://assets.myntassets.com/v1/images/style/p...   9355.jpg
# 21246  http://assets.myntassets.com/v1/images/style/p...  46862.jpg
# 3871   http://assets.myntassets.com/v1/images/style/p...  29115.jpg
# 13015  http://assets.myntassets.com/v1/images/style/p...  53806.jpg
#
# [300 rows x 12 columns]

# %%
options_sunglasses = ['Black', 'Brown']
sunglasses = df[(df['articleType'] == 'Sunglasses') & (df['baseColour'].isin(options_sunglasses))]
sunglasses = shuffle(sunglasses)
sunglasses = sunglasses.head(200)

# %%
sunglasses.groupby('baseColour')['baseColour'].count().nlargest()
# Out:
# baseColour
# Black    108
# Brown     92
# Name: baseColour, dtype: int64

# %%
options_watch = ['Black', 'White', 'Silver']
watch = df[(df['articleType'] == 'Watch') & (df['baseColour'].isin(options_watch))]
watch = shuffle(watch)
watch = watch.head(500)

# %%
watch.groupby('baseColour')['baseColour'].count().nlargest()
# Out:
# baseColour
# Black     271
# White     171
# Silver     58
# Name: baseColour, dtype: int64

# %%
options_tshirt = ['Black', 'White']
tshirts = df[(df['articleType'] == 'Tshirts') & (df['baseColour'].isin(options_tshirt) & (df['usage'] == 'Casual'))]
tshirts = shuffle(tshirts)
tshirts = tshirts.head(300)

# %%
tshirts.groupby('baseColour')['baseColour'].count().nlargest()
# Out:
# baseColour
# White    162
# Black    138
# Name: baseColour, dtype: int64

# %%
options_shoes = ['Black', 'White']
option_s = ['Formal Shoes', 'Casual Shoes']
option_gen = ['Men', 'Women']
options_usage = ['Casual', 'Formal']
shoes = df[(df['articleType'].isin(option_s)) & (df['baseColour'].isin(options_shoes) & (df['gender'].isin(option_gen)) & (df['usage'].isin(options_usage)))]
shoes = shuffle(shoes)
shoes = shoes.head(500)

# %%
shoes.groupby('usage')['usage'].count().nlargest()
# Out:
# usage
# Casual    361
# Formal    139
# Name: usage, dtype: int64

# %%
frames = [ring, ties, nailpolish, deodrant, jeans, trousers, socks, sunglasses, watch, tshirts, shoes]
result = pd.concat(frames)

# %%
result
# Out:
#           id gender masterCategory subCategory   articleType baseColour  \
# 121    49005  Women    Accessories   Jewellery          Ring     Silver
# 576    48927  Women    Accessories   Jewellery          Ring     Silver
# 736    49034  Women    Accessories   Jewellery          Ring     Silver
# 1060   48929  Women    Accessories   Jewellery          Ring     Silver
# 1094   49033  Women    Accessories   Jewellery          Ring     Silver
# ...      ...    ...            ...         ...           ...        ...
# 966    26536    Men       Footwear       Shoes  Casual Shoes      White
# 40538  44767    Men       Footwear       Shoes  Casual Shoes      White
# 602    10634    Men       Footwear       Shoes  Formal Shoes      Black
# 8568   36481    Men       Footwear       Shoes  Casual Shoes      Black
# 41012  18872    Men       Footwear       Shoes  Formal Shoes      Black
#
#        season  year   usage                               productDisplayName  \
# 121    Summer  2012  Casual                         Lucera Women Silver Ring
# 576    Summer  2012  Casual                         Lucera Women Silver Ring
# 736    Summer  2012  Casual                         Lucera Women Silver Ring
# 1060     Fall  2012  Casual                         Lucera Women Silver Ring
# 1094   Summer  2012  Casual                         Lucera Women Silver Ring
# ...       ...   ...     ...                                              ...
# 966    Summer  2012  Casual                               ID Men White Shoes
# 40538  Summer  2012  Casual                Globalite Men White Eclipse Shoes
# 602    Winter  2012  Formal  Carlton London Men Black Oxford Wingtip Brogues
# 8568   Summer  2012  Casual                    Spinn Men Black Elevate Shoes
# 41012    Fall  2012  Formal              Franco Leone Men Formal Black Shoes
#
#                                                    image   filename
# 121    http://assets.myntassets.com/v1/images/style/p...  49005.jpg
# 576    http://assets.myntassets.com/v1/images/style/p...  48927.jpg
# 736    http://assets.myntassets.com/v1/images/style/p...  49034.jpg
# 1060   http://assets.myntassets.com/v1/images/style/p...  48929.jpg
# 1094   http://assets.myntassets.com/v1/images/style/p...  49033.jpg
# ...                                                  ...        ...
# 966    http://assets.myntassets.com/v1/images/style/p...  26536.jpg
# 40538  http://assets.myntassets.com/v1/images/style/p...  44767.jpg
# 602    http://assets.myntassets.com/v1/images/style/p...  10634.jpg
# 8568   http://assets.myntassets.com/v1/images/style/p...  36481.jpg
# 41012  http://assets.myntassets.com/v1/images/style/p...  18872.jpg
#
# [3216 rows x 12 columns]

# %%
from sklearn.utils import shuffle
new_df = shuffle(result)
new_df = shuffle(new_df)

# %%
rest_new_df = new_df.reset_index()

# %%
rest_new_df.drop('index', axis=1, inplace=True)

# %%
import random
amount = []
for x in range(3216):
    price = random.randint(5, 40) * 5
    amount.append(float(price))

rest_new_df['price'] = amount

# %%
rest_new_df
# Out:
#          id gender masterCategory subCategory  articleType baseColour  season  \
# 0     10060    Men        Apparel     Topwear      Tshirts      White    Fall
# 1     23766    Men    Accessories     Eyewear   Sunglasses      Black  Winter
# 2     37332  Women    Accessories       Watch        Watch      White  Winter
# 3     56464  Women  Personal Care       Nails  Nail Polish       Pink  Spring
# 4     13506    Men        Apparel     Topwear      Tshirts      White    Fall
# ...     ...    ...            ...         ...          ...        ...     ...
# 3211  37329  Women    Accessories       Watch        Watch      White  Winter
# 3212  18581    Men    Accessories       Socks        Socks      Black  Summer
# 3213  55880  Women  Personal Care       Nails  Nail Polish     Silver  Spring
# 3214  29433    Men    Accessories       Watch        Watch      White  Winter
# 3215  43194  Women    Accessories       Watch        Watch      White  Winter
#
#       year   usage                          productDisplayName  \
# 0     2011  Casual      Puma Men motor sport tee White Tshirts
# 1     2016  Casual     Oakley Men Black Fast Jacket Sunglasses
# 2     2016  Casual          DKNY Women White Dial Watch NY8482
# 3     2017  Casual       Streetwear Pink Petals Nail Polish 34
# 4     2011  Casual      Chimp Men Color me Happy White Tshirts
# ...    ...     ...                                         ...
# 3211  2016  Casual    Casio Sheen Women White Dial Watch SX048
# 3212  2011  Casual       Puma Men Formstripe Short Black Socks
# 3213  2017  Casual          Colorbar Exclusive Nail Lacquer 56
# 3214  2016  Casual               Giordano Men White Dial Watch
# 3215  2016  Casual  Fastrack Women White Dial Watch NA2049SM09
#
#                                                   image   filename  price
# 0     http://assets.myntassets.com/v1/images/style/p...  10060.jpg   40.0
# 1     http://assets.myntassets.com/v1/images/style/p...  23766.jpg  135.0
# 2     http://assets.myntassets.com/v1/images/style/p...  37332.jpg  120.0
# 3     http://assets.myntassets.com/v1/images/style/p...  56464.jpg  145.0
# 4     http://assets.myntassets.com/v1/images/style/p...  13506.jpg  130.0
# ...                                                 ...        ...    ...
# 3211  http://assets.myntassets.com/v1/images/style/p...  37329.jpg  130.0
# 3212  http://assets.myntassets.com/v1/images/style/p...  18581.jpg  100.0
# 3213  http://assets.myntassets.com/assets/images/558...  55880.jpg  165.0
# 3214  http://assets.myntassets.com/v1/images/style/p...  29433.jpg  180.0
# 3215  http://assets.myntassets.com/v1/images/style/p...  43194.jpg  190.0
#
# [3216 rows x 13 columns]

# %%
rest_new_df.to_csv('products_data.csv', index=False)

# %%
df.groupby('subCategory')['subCategory'].count().nlargest(20)
# Out:
# subCategory
# Topwear                     15390
# Shoes                        7324
# Bags                         3053
# Bottomwear                   2686
# Watch                        2542
# Innerwear                    1806
# Jewellery                    1080
# Eyewear                      1073
# Fragrance                    1002
# Sandal                        961
# Wallets                       925
# Flip Flops                    915
# Belts                         811
# Socks                         698
# Dress                         478
# Loungewear and Nightwear      464
# Saree                         427
# Lips                          425
# Headwear                      293
# Nails                         278
# Name: subCategory, dtype: int64

# %%
df.groupby('articleType')['articleType'].count().nlargest(50)
# Out:
# articleType
# Tshirts                  7069
# Shirts                   3214
# Casual Shoes             2846
# Watch                    2542
# Sports Shoes             2016
# Kurtas                   1844
# Tops                     1762
# Handbags                 1759
# Heels                    1323
# Sunglasses               1073
# Wallets                   928
# Flip Flops                916
# Sandals                   895
# Briefs                    847
# Belts                     813
# Backpacks                 724
# Socks                     686
# Formal Shoes              637
# Perfume and Body Mist     604
# Jeans                     603
# Shorts                    547
# Trousers                  530
# Flats                     500
# Bra                       477
# Dresses                   464
# Sarees                    427
# Earrings                  417
# Deodorant                 347
# Track Pants               304
# Clutches                  288
# Sweatshirts               285
# Caps                      283
# Nail Polish               278
# Sweaters                  277
# Ties                      263
# Lipstick                  260
# Jackets                   258
# Innerwear Vests           242
# Kurtis                    234
# Tunics                    229
# Nightdress                188
# Leggings                  177
# Pendant                   176
# Capris                    175
# Necklace and Chains       160
# Night suits               141
# Trunk                     140
# Skirts                    128
# Scarves                   119
# Ring                      118
# Name: articleType, dtype: int64

# %%
# Taking 5000 samples for now.
samples_df = rest_new_df

# %%
samples_df
# Out:
#          id gender masterCategory subCategory  articleType baseColour  season  \
# 0     10060    Men        Apparel     Topwear      Tshirts      White    Fall
# 1     23766    Men    Accessories     Eyewear   Sunglasses      Black  Winter
# 2     37332  Women    Accessories       Watch        Watch      White  Winter
# 3     56464  Women  Personal Care       Nails  Nail Polish       Pink  Spring
# 4     13506    Men        Apparel     Topwear      Tshirts      White    Fall
# ...     ...    ...            ...         ...          ...        ...     ...
# 3211  37329  Women    Accessories       Watch        Watch      White  Winter
# 3212  18581    Men    Accessories       Socks        Socks      Black  Summer
# 3213  55880  Women  Personal Care       Nails  Nail Polish     Silver  Spring
# 3214  29433    Men    Accessories       Watch        Watch      White  Winter
# 3215  43194  Women    Accessories       Watch        Watch      White  Winter
#
#       year   usage                          productDisplayName  \
# 0     2011  Casual      Puma Men motor sport tee White Tshirts
# 1     2016  Casual     Oakley Men Black Fast Jacket Sunglasses
# 2     2016  Casual          DKNY Women White Dial Watch NY8482
# 3     2017  Casual       Streetwear Pink Petals Nail Polish 34
# 4     2011  Casual      Chimp Men Color me Happy White Tshirts
# ...    ...     ...                                         ...
# 3211  2016  Casual    Casio Sheen Women White Dial Watch SX048
# 3212  2011  Casual       Puma Men Formstripe Short Black Socks
# 3213  2017  Casual          Colorbar Exclusive Nail Lacquer 56
# 3214  2016  Casual               Giordano Men White Dial Watch
# 3215  2016  Casual  Fastrack Women White Dial Watch NA2049SM09
#
#                                                   image   filename  price
# 0     http://assets.myntassets.com/v1/images/style/p...  10060.jpg   40.0
# 1     http://assets.myntassets.com/v1/images/style/p...  23766.jpg  135.0
# 2     http://assets.myntassets.com/v1/images/style/p...  37332.jpg  120.0
# 3     http://assets.myntassets.com/v1/images/style/p...  56464.jpg  145.0
# 4     http://assets.myntassets.com/v1/images/style/p...  13506.jpg  130.0
# ...                                                 ...        ...    ...
# 3211  http://assets.myntassets.com/v1/images/style/p...  37329.jpg  130.0
# 3212  http://assets.myntassets.com/v1/images/style/p...  18581.jpg  100.0
# 3213  http://assets.myntassets.com/assets/images/558...  55880.jpg  165.0
# 3214  http://assets.myntassets.com/v1/images/style/p...  29433.jpg  180.0
# 3215  http://assets.myntassets.com/v1/images/style/p...  43194.jpg  190.0
#
# [3216 rows x 13 columns]

# %%
import random
amount = []
for x in range(3183):
    price = random.randint(5, 40) * 5
    amount.append(float(price))

samples_df['price'] = amount

# %%
samples_df
# Out:
#          id gender masterCategory subCategory  articleType baseColour  season  \
# 0     10060    Men        Apparel     Topwear      Tshirts      White    Fall
# 1     23766    Men    Accessories     Eyewear   Sunglasses      Black  Winter
# 2     37332  Women    Accessories       Watch        Watch      White  Winter
# 3     56464  Women  Personal Care       Nails  Nail Polish       Pink  Spring
# 4     13506    Men        Apparel     Topwear      Tshirts      White    Fall
# ...     ...    ...            ...         ...          ...        ...     ...
# 3211  37329  Women    Accessories       Watch        Watch      White  Winter
# 3212  18581    Men    Accessories       Socks        Socks      Black  Summer
# 3213  55880  Women  Personal Care       Nails  Nail Polish     Silver  Spring
# 3214  29433    Men    Accessories       Watch        Watch      White  Winter
# 3215  43194  Women    Accessories       Watch        Watch      White  Winter
#
#       year   usage                          productDisplayName  \
# 0     2011  Casual      Puma Men motor sport tee White Tshirts
# 1     2016  Casual     Oakley Men Black Fast Jacket Sunglasses
# 2     2016  Casual          DKNY Women White Dial Watch NY8482
# 3     2017  Casual       Streetwear Pink Petals Nail Polish 34
# 4     2011  Casual      Chimp Men Color me Happy White Tshirts
# ...    ...     ...                                         ...
# 3211  2016  Casual    Casio Sheen Women White Dial Watch SX048
# 3212  2011  Casual       Puma Men Formstripe Short Black Socks
# 3213  2017  Casual          Colorbar Exclusive Nail Lacquer 56
# 3214  2016  Casual               Giordano Men White Dial Watch
# 3215  2016  Casual  Fastrack Women White Dial Watch NA2049SM09
#
#                                                   image   filename  price
# 0     http://assets.myntassets.com/v1/images/style/p...  10060.jpg   40.0
# 1     http://assets.myntassets.com/v1/images/style/p...  23766.jpg  135.0
# 2     http://assets.myntassets.com/v1/images/style/p...  37332.jpg  120.0
# 3     http://assets.myntassets.com/v1/images/style/p...  56464.jpg  145.0
# 4     http://assets.myntassets.com/v1/images/style/p...  13506.jpg  130.0
# ...                                                 ...        ...    ...
# 3211  http://assets.myntassets.com/v1/images/style/p...  37329.jpg  130.0
# 3212  http://assets.myntassets.com/v1/images/style/p...  18581.jpg  100.0
# 3213  http://assets.myntassets.com/assets/images/558...  55880.jpg  165.0
# 3214  http://assets.myntassets.com/v1/images/style/p...  29433.jpg  180.0
# 3215  http://assets.myntassets.com/v1/images/style/p...  43194.jpg  190.0
#
# [3216 rows x 13 columns]

# %%
from sklearn.utils import shuffle
samples_df = shuffle(samples_df)

# %%
samples_df.to_csv('products_data.csv', index=False)

# %%
samples_df[samples_df['articleType'] == 'Mufflers']
# Out:
# Empty DataFrame
# Columns: [id, gender, masterCategory, subCategory, articleType, baseColour, season, year, usage, productDisplayName, image, filename, price]
# Index: []

# %%
samples_df['articleType'].values
# Out:
# array(['Jeans', 'Jeans', 'Sunglasses', ..., 'Tshirts', 'Ties', 'Watch'],
#       dtype=object)

# %%
samples_df.groupby('subCategory')['subCategory'].count().nlargest(142)
# Out:
# subCategory
# Topwear                     1620
# Shoes                        855
# Bags                         387
# Watch                        324
# Bottomwear                   310
# Innerwear                    227
# Jewellery                    147
# Fragrance                    129
# Sandal                       114
# Wallets                      109
# Flip Flops                   108
# Belts                        100
# Eyewear                       98
# Socks                         68
# Lips                          65
# Dress                         53
# Loungewear and Nightwear      52
# Headwear                      41
# Saree                         34
# Ties                          26
# Makeup                        20
# Nails                         18
# Apparel Set                   17
# Accessories                   15
# Free Gifts                    14
# Scarves                       13
# Mufflers                       9
# Skin                           9
# Skin Care                      6
# Shoe Accessories               3
# Eyes                           3
# Gloves                         1
# Sports Accessories             1
# Cufflinks                      1
# Beauty Accessories             1
# Bath and Body                  1
# Water Bottle                   1
# Name: subCategory, dtype: int64

# %%
samples_df.to_csv('5000samples.csv')

# %%
# Taking the respective images of the products of 1000 samples
dir_src = r"D:\\data\\images"
dir_dst = r"images"
for root, _, files in os.walk(dir_src):
    for img in tqdm(files):
        if img in samples_df['filename'].values:
             copy(os.path.join(root, img), dir_dst)
# Out:
# 100%|██████████| 44441/44441 [01:43<00:00, 429.96it/s]

# %%
model = ResNet50(weights="imagenet", include_top=False, input_shape=(60,80,3))
model.trainable = False

model = tensorflow.keras.Sequential([
    model,
    GlobalMaxPooling2D()
])

# %%
model.save("product_model.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# C:\Users\Ellefson\miniconda3\envs\product-ai\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
def feature_extraction(img_path, model):
    img = image.load_img(img_path, target_size=(60,80))
    img_array = image.img_to_array(img)
    expanded_img_array = np.expand_dims(img_array, axis=0)
    preprocessed_img = preprocess_input(expanded_img_array)
    result = model.predict(preprocessed_img).flatten()
    normalized_result = result /  norm(result)

    return normalized_result

# %%
filenames = []

for file in os.listdir('images'):
    filenames.append(os.path.join('images', file))

feature_list = []

for file in tqdm(filenames):
    feature_list.append(feature_extraction(file, model))
# Out:
#  68%|██████▊   | 2195/3215 [03:53<01:48,  9.38it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11556\1942948929.py in <module>
#       7
#       8 for file in tqdm(filenames):
# ----> 9     feature_list.append(feature_extraction(file, model))
#
# ~\AppData\Local\Temp\ipykernel_11556\3592276982.py in feature_extraction(img_path, model)
#       4     expanded_img_array = np.expand_dims(img_array, axis=0)
#       5     preprocessed_img = preprocess_input(expanded_img_array)
# ----> 6     result = model.predict(preprocessed_img).flatten()
#       7     normalized_result = result /  norm(result)
#       8
#
# ~\miniconda3\envs\product-ai\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\miniconda3\envs\product-ai\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1783       callbacks.on_predict_begin()
#    1784       batch_outputs = None
# -> 1785       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1786         with data_handler.catch_stop_iteration():
#    1787           for step in data_handler.steps():
#
# ~\miniconda3\envs\product-ai\lib\site-packages\keras\engine\data_adapter.py in enumerate_epochs(self)
#    1193     """Yields `(epoch, tf.data.Iterator)`."""
#    1194     with self._truncate_execution_to_epoch():
# -> 1195       data_iterator = iter(self._dataset)
#    1196       for epoch in range(self._initial_epoch, self._epochs):
#    1197         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# ~\miniconda3\envs\product-ai\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __iter__(self)
#     488     if context.executing_eagerly() or ops.inside_function():
#     489       with ops.colocate_with(self._variant_tensor):
# --> 490         return iterator_ops.OwnedIterator(self)
#     491     else:
#     492       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# ~\miniconda3\envs\product-ai\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in __init__(self, dataset, components, element_spec)
#     724             "When `dataset` is provided, `element_spec` and `components` must "
#     725             "not be specified.")
# --> 726       self._create_iterator(dataset)
#     727
#     728     self._get_next_call_count = 0
#
# ~\miniconda3\envs\product-ai\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in _create_iterator(self, dataset)
#     749               output_types=self._flat_output_types,
#     750               output_shapes=self._flat_output_shapes))
# --> 751       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     752       # Delete the resource when this object is deleted
#     753       self._resource_deleter = IteratorResourceDeleter(
#
# ~\miniconda3\envs\product-ai\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3235     try:
#    3236       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 3237         _ctx, "MakeIterator", name, dataset, iterator)
#    3238       return _result
#    3239     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
joblib.dump(filenames, "file_name_1.pkl")
# Out:
# ['file_name_1.pkl']

# %%
joblib.dump(feature_list, "image_embed_1.pkl")
# Out:
# ['image_embed_1.pkl']

# %%
ds = np.array(joblib.load(open('image-embed.pkl', 'rb')))
