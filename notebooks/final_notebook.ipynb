# %%
import joblib
import numpy as np
import pandas as pd
import tensorflow
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.preprocessing import image
from tensorflow import keras
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from numpy.linalg import norm
from sklearn.neighbors import NearestNeighbors
from PIL import Image
import requests
from tqdm import tqdm
import os
from shutil import copy

# %%
# Reading the Dataset having aaprox. 44000 records
df = pd.read_csv('../data/dataset/newdata.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
# Taking 1000 samples for now.
samples_df = df.head(10000)

# %%
samples_df
# Out:
#          id gender masterCategory subCategory   articleType baseColour  \
# 0     15970    Men        Apparel     Topwear        Shirts  Navy Blue
# 1     39386    Men        Apparel  Bottomwear         Jeans       Blue
# 2     59263  Women    Accessories     Watches       Watches     Silver
# 3     21379    Men        Apparel  Bottomwear   Track Pants      Black
# 4     53759    Men        Apparel     Topwear       Tshirts       Grey
# ...     ...    ...            ...         ...           ...        ...
# 9995  43685   Boys        Apparel     Topwear       Tshirts      White
# 9996  16487    Men        Apparel     Topwear       Tshirts       Blue
# 9997  51340    Men    Accessories       Socks         Socks      Beige
# 9998   6102    Men        Apparel     Topwear       Tshirts      Black
# 9999  47225    Men       Footwear       Shoes  Formal Shoes      Black
#
#       season  year   usage                             productDisplayName  \
# 0       Fall  2011  Casual               Turtle Check Men Navy Blue Shirt
# 1     Summer  2012  Casual             Peter England Men Party Blue Jeans
# 2     Winter  2016  Casual                       Titan Women Silver Watch
# 3       Fall  2011  Casual  Manchester United Men Solid Black Track Pants
# 4     Summer  2012  Casual                          Puma Men Grey T-shirt
# ...      ...   ...     ...                                            ...
# 9995  Summer  2012  Casual              Doodle Boys Printed White T-shirt
# 9996    Fall  2011  Casual               Locomotive Men Solid Blue TShirt
# 9997  Summer  2016  Casual                        Raymond Men Beige Socks
# 9998  Summer  2011  Casual       UCB Men's Benetton Details Black T-shirt
# 9999  Summer  2012  Formal            Franco Leone Men Black Formal Shoes
#
#                                                   image   filename
# 0     http://assets.myntassets.com/v1/images/style/p...  15970.jpg
# 1     http://assets.myntassets.com/v1/images/style/p...  39386.jpg
# 2     http://assets.myntassets.com/v1/images/style/p...  59263.jpg
# 3     http://assets.myntassets.com/v1/images/style/p...  21379.jpg
# 4     http://assets.myntassets.com/v1/images/style/p...  53759.jpg
# ...                                                 ...        ...
# 9995  http://assets.myntassets.com/v1/images/style/p...  43685.jpg
# 9996  http://assets.myntassets.com/v1/images/style/p...  16487.jpg
# 9997  http://assets.myntassets.com/v1/images/style/p...  51340.jpg
# 9998  http://assets.myntassets.com/v1/images/style/p...   6102.jpg
# 9999  http://assets.myntassets.com/v1/images/style/p...  47225.jpg
#
# [10000 rows x 12 columns]

# %%
import random
amount = []
for x in range(10000):
    price = random.randint(5, 45) * 5
    amount.append(float(price))

samples_df['price'] = amount
# Out:
# C:\Users\Ellefson\miniconda3\envs\product-ai\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
from sklearn.utils import shuffle
samples_df = shuffle(samples_df)

# %%
samples_df
# Out:
#          id  gender masterCategory subCategory            articleType  \
# 1743  55400   Women  Personal Care      Makeup     Kajal and Eyeliner
# 3194  26198     Men  Personal Care   Fragrance  Perfume and Body Mist
# 3641  35116   Women    Accessories   Jewellery    Necklace and Chains
# 4018  53131   Women       Footwear       Shoes                  Heels
# 6591  13992   Women       Footwear       Shoes           Sports Shoes
# ...     ...     ...            ...         ...                    ...
# 7660   7217     Men       Footwear       Shoes           Formal Shoes
# 4817   4316  Unisex        Apparel     Topwear                Tshirts
# 1788  16303     Men        Apparel     Topwear                 Shirts
# 6797  34111   Girls        Apparel     Topwear                   Tops
# 2373  56278   Women        Apparel   Innerwear                    Bra
#
#      baseColour  season  year   usage  \
# 1743   Charcoal  Spring  2017  Casual
# 3194       Blue  Spring  2017  Casual
# 3641      Black  Summer  2012  Casual
# 4018       Gold  Winter  2015  Casual
# 6591       Grey    Fall  2011  Sports
# ...         ...     ...   ...     ...
# 7660      Black    Fall  2011  Formal
# 4817      Black  Summer  2011  Casual
# 1788  Navy Blue    Fall  2011  Casual
# 6797  Navy Blue  Summer  2012  Casual
# 2373       Skin  Summer  2017  Casual
#
#                                     productDisplayName  \
# 1743           Revlon Grow Luscious Graphite Eye Liner
# 3194                       Formula 1 Start Men Perfume
# 3641                  Allen Solly Woman Black Necklace
# 4018            Catwalk Women Gold Toned & Brown Flats
# 6591           Puma Women Body Train Grey Sports Shoes
# ...                                                ...
# 7660            Rockport Men Carnforth Soft Black Shoe
# 4817    Tantra Kid's Unisex Play To Win Black Kidswear
# 1788           Peter England Men Check Navy Blue Shirt
# 6797                Doodle Girls Striped Navy Blue Top
# 2373  Biara Skin Coloured Everyday Support Bra MW 1002
#
#                                                   image   filename  price
# 1743  http://assets.myntassets.com/v1/images/style/p...  55400.jpg   30.0
# 3194  http://assets.myntassets.com/v1/images/style/p...  26198.jpg   25.0
# 3641  http://assets.myntassets.com/v1/images/style/p...  35116.jpg   65.0
# 4018  http://assets.myntassets.com/v1/images/style/p...  53131.jpg   95.0
# 6591  http://assets.myntassets.com/v1/images/style/p...  13992.jpg  100.0
# ...                                                 ...        ...    ...
# 7660  http://assets.myntassets.com/assets/images/721...   7217.jpg  125.0
# 4817  http://assets.myntassets.com/v1/images/style/p...   4316.jpg   90.0
# 1788  http://assets.myntassets.com/v1/images/style/p...  16303.jpg  170.0
# 6797  http://assets.myntassets.com/v1/images/style/p...  34111.jpg   65.0
# 2373  http://assets.myntassets.com/v1/images/style/p...  56278.jpg   30.0
#
# [10000 rows x 13 columns]

# %%
samples_df.to_csv('10000samples.csv')

# %%
# Taking the respective images of the products of 1000 samples
dir_src = r"D:\\data\\images"
dir_dst = r"images"
for root, _, files in os.walk(dir_src):
    for img in files:
        if img in samples_df['filename'].values:
             copy(os.path.join(root, img), dir_dst)

# %%
model = ResNet50(weights="imagenet", include_top=False, input_shape=(60,80,3))
model.trainable = False

model = tensorflow.keras.Sequential([
    model,
    GlobalMaxPooling2D()
])

# %%
def feature_extraction(img_path, model):
    img = image.load_img(img_path, target_size=(60,80))
    img_array = image.img_to_array(img)
    expanded_img_array = np.expand_dims(img_array, axis=0)
    preprocessed_img = preprocess_input(expanded_img_array)
    result = model.predict(preprocessed_img).flatten()
    normalized_result = result /  norm(result)

    return normalized_result

# %%
filenames = []

for file in os.listdir('images'):
    filenames.append(os.path.join('images', file))

feature_list = []

for file in tqdm(filenames):
    feature_list.append(feature_extraction(file, model))
# Out:
# 100%|██████████| 9999/9999 [17:43<00:00,  9.41it/s]

# %%
joblib.dump(filenames, "filenames.pkl")
# Out:
# ['filenames.pkl']

# %%
joblib.dump(feature_list, "image-embed.pkl")
# Out:
# ['image-embed.pkl']

# %%
ds = np.array(joblib.load(open('image-embed.pkl', 'rb')))
